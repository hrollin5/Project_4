# %%
import pandas as pd
from pathlib import Path
import re

# %%
# Set the limit for max rows and columns to display
pd.options.display.max_rows = 50
pd.options.display.max_columns = 50

# %%
#big_path = "../../../Traffic_Violations.csv"
big_path = "data\Traffic_Violations.csv"
big_df = pd.read_csv(big_path, low_memory=False)

# %%
big_df.head()

# %%
big_df.columns

# %%
# Drop the columns that we have deemed unhelpful
big_df_smaller = big_df.drop(["Agency", "Geolocation", "VehicleType", "HAZMAT", 
                                "Commercial Vehicle", "Commercial License", "Article", "Charge", 
                                "SeqID", "SubAgency", "Model", "Contributed To Accident", "Driver State", 
                                "Driver City", "Arrest Type", "Search Reason For Stop"], axis = 1)

# %%
# Drop rows that do not result in a citation or warning
big_df_smaller.drop(big_df_smaller[big_df_smaller['Violation Type'] == 'ESERO'].index, inplace=True)
big_df_smaller.drop(big_df_smaller[big_df_smaller['Violation Type'] == 'SERO'].index, inplace=True)

# %%
# Clean the Year column
# Drop rows with null year
big_df_smaller = big_df_smaller.dropna(subset=["Year"])
# Change year to integer
big_df_smaller["Year"]= big_df_smaller["Year"].astype(int)
# Get years in a list
years = big_df_smaller["Year"].unique()
# Make a list of garbage years
years_to_remove = [0, 6338, 1005, 1196, 2912, 1009, 2088, 1007, 2102, 2109, 2105, 2997]
# Clean the list of years
good_years = [value for value in years if value not in years_to_remove]
# Keep only rows with good years
big_df_smaller = big_df_smaller[big_df_smaller["Year"].isin(good_years)]
big_df_smaller.shape
# Out:
# (1790375, 27)

# %%
# Keep only data that has latitude and longitude
big_df_smaller = big_df_smaller[(big_df_smaller['Latitude'] != 0) & (big_df_smaller['Longitude'] != 0)]

# %%
big_df_smaller.columns
# Out:
# Index(['Date Of Stop', 'Time Of Stop', 'Description', 'Location', 'Latitude',
#        'Longitude', 'Accident', 'Belts', 'Personal Injury', 'Property Damage',
#        'Fatal', 'Alcohol', 'Work Zone', 'Search Conducted',
#        'Search Disposition', 'Search Outcome', 'Search Reason', 'Search Type',
#        'Search Arrest Reason', 'State', 'Year', 'Make', 'Color',
#        'Violation Type', 'Race', 'Gender', 'DL State'],
#       dtype='object')

# %%
big_df_smaller.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1665844 entries, 1 to 1878004
# Data columns (total 27 columns):
#  #   Column                Non-Null Count    Dtype
# ---  ------                --------------    -----
#  0   Date Of Stop          1665844 non-null  object
#  1   Time Of Stop          1665844 non-null  object
#  2   Description           1665836 non-null  object
#  3   Location              1665841 non-null  object
#  4   Latitude              1665844 non-null  float64
#  5   Longitude             1665844 non-null  float64
#  6   Accident              1665844 non-null  object
#  7   Belts                 1665844 non-null  object
#  8   Personal Injury       1665844 non-null  object
#  9   Property Damage       1665844 non-null  object
#  10  Fatal                 1665844 non-null  object
#  11  Alcohol               1665844 non-null  object
#  12  Work Zone             1665844 non-null  object
#  13  Search Conducted      1023793 non-null  object
#  14  Search Disposition    71352 non-null    object
#  15  Search Outcome        1006152 non-null  object
#  16  Search Reason         71352 non-null    object
#  17  Search Type           71344 non-null    object
#  18  Search Arrest Reason  48011 non-null    object
#  19  State                 1665794 non-null  object
#  20  Year                  1665844 non-null  int32
#  21  Make                  1665800 non-null  object
#  22  Color                 1655576 non-null  object
#  23  Violation Type        1665844 non-null  object
#  24  Race                  1665844 non-null  object
#  25  Gender                1665844 non-null  object
#  26  DL State              1665120 non-null  object
# dtypes: float64(2), int32(1), object(24)
# memory usage: 349.5+ MB

# %%
# null_count = big_df_smaller['Accident'].isnull().sum()
# null_count

# %%
# if big_df_smaller.isnull().values.any():
#     print("There are null values in the DataFrame.")
# else:
#     print("There are no null values in the DataFrame.")

# %%
# big_df_smaller[['Fatal', 'Alcohol', 'Work Zone', 'Search Conducted',
#        'Search Disposition', 'Search Outcome', 'Search Reason']].isnull()

# %%
# # Check the number of null values in each column
# null_count_per_column = big_df_smaller.isnull().sum()

# # Display the result
# print("Number of null values in each column:")
# print(null_count_per_column)

# %%
# big_df_smaller["Search Reason"].value_counts(dropna = False)

# %%
big_df_smaller['Date Of Stop'] = pd.to_datetime(big_df_smaller['Date Of Stop'])
big_df_smaller['Year Date'] = big_df_smaller['Date Of Stop'].dt.year
big_df_smaller['Month'] = big_df_smaller['Date Of Stop'].dt.month
big_df_smaller['Day'] = big_df_smaller['Date Of Stop'].dt.day
random_forest_df = big_df_smaller.drop(['Date Of Stop'], axis = 1)

# %%
# Drop rows with null Description
big_df_smaller = big_df_smaller.dropna(subset=["Description"])

# %%
# Use Regex to replace any description including speeding with just "Speeding"
pattern = re.compile(r'.*EXCEEDING.*SPEED LIMIT.*', flags=re.IGNORECASE)

big_df_smaller['Description'] = big_df_smaller['Description'].apply(lambda x: re.sub(pattern, 'Speeding', x))

# %%
big_df_smaller["Description"].nunique()
# Out:
# 14529

# %%
# Use Regex to replace any description including speeding with just "Speeding"
pattern = re.compile(r'.*FAILURE.*YIELD.*', flags=re.IGNORECASE)

big_df_smaller['Description'] = big_df_smaller['Description'].apply(lambda x: re.sub(pattern, 'Failure to Yield', x))

# %%
# Use Regex to replace any description including speeding with just "Speeding"
pattern = re.compile(r'.*FAIL.*YIELD.*', flags=re.IGNORECASE)

big_df_smaller['Description'] = big_df_smaller['Description'].apply(lambda x: re.sub(pattern, 'Failure to Yield', x))

# %%
# Use Regex to replace any description including speeding with just "Speeding"
pattern = re.compile(r'.*LEARNER.*PERMIT.*', flags=re.IGNORECASE)

big_df_smaller['Description'] = big_df_smaller['Description'].apply(lambda x: re.sub(pattern, 'Learners Permit', x))

# %%
big_df_smaller["Description"].nunique()
# Out:
# 14241

# %%
# Use Regex to replace any description including speeding with just "Speeding"
pattern = re.compile(r'.*SPEED.*', flags=re.IGNORECASE)

big_df_smaller['Description'] = big_df_smaller['Description'].apply(lambda x: re.sub(pattern, 'Speeding', x))

# %%
# Use Regex to replace any description including speeding with just "Speeding"
pattern = re.compile(r'.*SPEEDING.*', flags=re.IGNORECASE)

big_df_smaller['Description'] = big_df_smaller['Description'].apply(lambda x: re.sub(pattern, 'Speeding', x))

# %%
big_df_smaller["Description"].nunique()
# Out:
# 11705

# %%
# Use Regex to replace any description including speeding with just "Speeding"
pattern = re.compile(r'.*LAMP.*', flags=re.IGNORECASE)

big_df_smaller['Description'] = big_df_smaller['Description'].apply(lambda x: re.sub(pattern, 'Improper Equipment', x))

# %%
# Use Regex to replace any description including speeding with just "Speeding"
pattern = re.compile(r'.*HEADLIGHT.*', flags=re.IGNORECASE)

big_df_smaller['Description'] = big_df_smaller['Description'].apply(lambda x: re.sub(pattern, 'Improper Equipment', x))

# %%
# Use Regex to replace any description including speeding with just "Speeding"
pattern = re.compile(r'.*REQUIRED.*MINIMUM.*EQUIPMENT.*', flags=re.IGNORECASE)

big_df_smaller['Description'] = big_df_smaller['Description'].apply(lambda x: re.sub(pattern, 'Improper Equipment', x))

# %%
# Use Regex to replace any description including speeding with just "Speeding"
pattern = re.compile(r'.*INOPERATIVE.*', flags=re.IGNORECASE)

big_df_smaller['Description'] = big_df_smaller['Description'].apply(lambda x: re.sub(pattern, 'Improper Equipment', x))

# %%
big_df_smaller["Description"].nunique()
# Out:
# 9413

# %%
# Use Regex to replace any description including speeding with just "Speeding"
pattern = re.compile(r'.*PARK.*', flags=re.IGNORECASE)

big_df_smaller['Description'] = big_df_smaller['Description'].apply(lambda x: re.sub(pattern, 'Non-Moving Violation', x))

# %%
# Use Regex to replace any description including speeding with just "Speeding"
pattern = re.compile(r'.*ABANDONING.*VEH.*', flags=re.IGNORECASE)

big_df_smaller['Description'] = big_df_smaller['Description'].apply(lambda x: re.sub(pattern, 'Non-Moving Violation', x))

# %%
big_df_smaller["Description"].nunique()
# Out:
# 9151

# %%
# Use Regex to replace any description including speeding with just "Speeding"
pattern = re.compile(r'.*INFLUENCE.*ALCOHOL.*', flags=re.IGNORECASE)

big_df_smaller['Description'] = big_df_smaller['Description'].apply(lambda x: re.sub(pattern, 'DUI', x))

# %%
# Use Regex to replace any description including speeding with just "Speeding"
pattern = re.compile(r'.*IMPAIRED.*ALCOHOL.*', flags=re.IGNORECASE)

big_df_smaller['Description'] = big_df_smaller['Description'].apply(lambda x: re.sub(pattern, 'DUI', x))

# %%
# Use Regex to replace any description including speeding with just "Speeding"
pattern = re.compile(r'.*FAILED.*STOP.*SIGN.*', flags=re.IGNORECASE)

big_df_smaller['Description'] = big_df_smaller['Description'].apply(lambda x: re.sub(pattern, 'Improper Stop', x))

# %%
# Use Regex to replace any description including speeding with just "Speeding"
pattern = re.compile(r'.*FAILURE.*STOP.*SIGN.*', flags=re.IGNORECASE)

big_df_smaller['Description'] = big_df_smaller['Description'].apply(lambda x: re.sub(pattern, 'Improper Stop', x))

# %%
# Use Regex to replace any description including speeding with just "Speeding"
pattern = re.compile(r'.*FAIL.*STOP.*SIGN.*', flags=re.IGNORECASE)

big_df_smaller['Description'] = big_df_smaller['Description'].apply(lambda x: re.sub(pattern, 'Improper Stop', x))

# %%
# Use Regex to replace any description including speeding with just "Speeding"
pattern = re.compile(r'.*FAILURE.*STOP.*SIGNAL.*', flags=re.IGNORECASE)

big_df_smaller['Description'] = big_df_smaller['Description'].apply(lambda x: re.sub(pattern, 'Improper Stop', x))

# %%
# Use Regex to replace any description including speeding with just "Speeding"
pattern = re.compile(r'.*FAILED.*STOP.*SIGNAL.*', flags=re.IGNORECASE)

big_df_smaller['Description'] = big_df_smaller['Description'].apply(lambda x: re.sub(pattern, 'Improper Stop', x))

# %%
# Use Regex to replace any description including speeding with just "Speeding"
pattern = re.compile(r'.*FAIL.*STOP.*SIGNAL.*', flags=re.IGNORECASE)

big_df_smaller['Description'] = big_df_smaller['Description'].apply(lambda x: re.sub(pattern, 'Improper Stop', x))

# %%
big_df_smaller["Description"].nunique()
# Out:
# 8767

# %%
# Use Regex to replace any description including speeding with just "Speeding"
pattern = re.compile(r'.*ELECTRONIC.*MSG.*', flags=re.IGNORECASE)

big_df_smaller['Description'] = big_df_smaller['Description'].apply(lambda x: re.sub(pattern, 'Texting', x))

# %%
big_df_smaller["Description"].nunique()
# Out:
# 8464

# %% [markdown]
# ### Function to replace the complete column value if a substring matches

# %%
# Function to replace a complete value if a substring matches
def data_cleanup(df, column_name, substring, replacement):
    mask = df[column_name].str.contains(substring, case=False)
    df.loc[mask, column_name] = replacement
    return df

# %%
# Replace Decription with REGISTRATION to 'Registration Violation'
column_to_modify = 'Description'
substring_to_match = 'REGISTRATION'
replacement_value = 'Registration Violation'
big_df_smaller = data_cleanup(big_df_smaller, column_to_modify, substring_to_match, replacement_value)

# %%
# Replace Decription with REGISTRATION to 'Registration Violation'
column_to_modify = 'Description'
substring_to_match = 'UNREGISTERED'
replacement_value = 'Registration Violation'
big_df_smaller = data_cleanup(big_df_smaller, column_to_modify, substring_to_match, replacement_value)

# %%
big_df_smaller["Description"].nunique()
# Out:
# 8012

# %%
# Replace Decription with SEATBELT to 'SeatBelt - Not restrained'
column_to_modify = 'Description'
substring_to_match = 'SEATBELT'
replacement_value = 'SeatBelt - Not restrained'
big_df_smaller = data_cleanup(big_df_smaller, column_to_modify, substring_to_match, replacement_value)

# %%
# Replace Decription with SEAT BELT to 'SeatBelt - Not restrained'
column_to_modify = 'Description'
substring_to_match = 'SEAT BELT'
replacement_value = 'SeatBelt - Not restrained'
big_df_smaller = data_cleanup(big_df_smaller, column_to_modify, substring_to_match, replacement_value)

# %%
big_df_smaller["Description"].nunique()
# Out:
# 6852

# %%
# Replace Decription with LICENSE to 'License Violation'
column_to_modify = 'Description'
substring_to_match = 'LICENSE'
replacement_value = 'License Violation'
big_df_smaller = data_cleanup(big_df_smaller, column_to_modify, substring_to_match, replacement_value)

# %%
big_df_smaller["Description"].nunique()
# Out:
# 7493

# %%
# Replace Decription with SUSPENDED to 'Suspended License or Registration'
column_to_modify = 'Description'
substring_to_match = 'SUSPENDED'
replacement_value = 'Suspended License or Registration'
big_df_smaller = data_cleanup(big_df_smaller, column_to_modify, substring_to_match, replacement_value)

# %%
# Replace Decription with LANE to 'Lane Violation'
column_to_modify = 'Description'
substring_to_match = 'LANE'
replacement_value = 'Lane Violation'
big_df_smaller = data_cleanup(big_df_smaller, column_to_modify, substring_to_match, replacement_value)

# %%
big_df_smaller["Description"].nunique()
# Out:
# 7062

# %%
# Replace Decription with UNINSURED to 'Uninsured Vehicle'
column_to_modify = 'Description'
substring_to_match = 'UNINSURED'
replacement_value = 'Uninsured Vehicle'
big_df_smaller = data_cleanup(big_df_smaller, column_to_modify, substring_to_match, replacement_value)

# %%
big_df_smaller["Description"].nunique()
# Out:
# 6953

# %%
# Replace Decription with FAILURE TO STOP to 'Failure to stop at different circumstances'
column_to_modify = 'Description'
substring_to_match = 'FAILURE TO STOP'
replacement_value = 'Failure to stop at different circumstances'
big_df_smaller = data_cleanup(big_df_smaller, column_to_modify, substring_to_match, replacement_value)

# %%
big_df_smaller["Description"].nunique()
# Out:
# 6692

# %%
# Use Regex to replace any description including speeding with just "Speeding"
pattern = re.compile(r'.*PHONE.*', flags=re.IGNORECASE)

big_df_smaller['Description'] = big_df_smaller['Description'].apply(lambda x: re.sub(pattern, 'Using Phone', x))

# %%
# Use Regex to replace any description including speeding with just "Speeding"
pattern = re.compile(r'.*TEXTMSG.*', flags=re.IGNORECASE)

big_df_smaller['Description'] = big_df_smaller['Description'].apply(lambda x: re.sub(pattern, 'Using Phone', x))

# %%
# Use Regex to replace any description including speeding with just "Speeding"
pattern = re.compile(r'.*TEXT.*', flags=re.IGNORECASE)

big_df_smaller['Description'] = big_df_smaller['Description'].apply(lambda x: re.sub(pattern, 'Using Phone', x))

# %%
big_df_smaller["Description"].nunique()
# Out:
# 6432

# %%
# Use Regex to replace any description including speeding with just "Speeding"
pattern = re.compile(r'.*TINT.*', flags=re.IGNORECASE)

big_df_smaller['Description'] = big_df_smaller['Description'].apply(lambda x: re.sub(pattern, 'Obstructed View', x))

# %%
# Use Regex to replace any description including speeding with just "Speeding"
pattern = re.compile(r'.*OBSTRUCTED.*', flags=re.IGNORECASE)

big_df_smaller['Description'] = big_df_smaller['Description'].apply(lambda x: re.sub(pattern, 'Obstructed View', x))

# %%
# Use Regex to replace any description including speeding with just "Speeding"
pattern = re.compile(r'.*RECKLESS.*', flags=re.IGNORECASE)

big_df_smaller['Description'] = big_df_smaller['Description'].apply(lambda x: re.sub(pattern, 'Reckless Driving', x))

# %%
# Use Regex to replace any description including speeding with just "Speeding"
pattern = re.compile(r'.*ACCIDENT.*', flags=re.IGNORECASE)

big_df_smaller['Description'] = big_df_smaller['Description'].apply(lambda x: re.sub(pattern, 'Involved in Accident', x))

# %%
# Use Regex to replace any description including speeding with just "Speeding"
pattern = re.compile(r'.*UNATTENDED.*DAMAGED.*', flags=re.IGNORECASE)

big_df_smaller['Description'] = big_df_smaller['Description'].apply(lambda x: re.sub(pattern, 'Involved in Accident', x))

# %%
big_df_smaller["Description"].nunique()
# Out:
# 5777

# %%
# Replace Decription with PRIVATE PROPERTY to 'Trespassing'
column_to_modify = 'Description'
substring_to_match = 'PRIVATE PROPERTY'
replacement_value = 'Trespassing'
big_df_smaller = data_cleanup(big_df_smaller, column_to_modify, substring_to_match, replacement_value)

# %%
big_df_smaller["Description"].nunique()
# Out:
# 5617

# %%
# Replace Decription with ' TURN' to 'Unsafe Turns'. Note the blank space before TURN to avoid replacing descriptions with 'RETURN'
column_to_modify = 'Description'
substring_to_match = ' TURN'
replacement_value = 'Unsafe Turns'
big_df_smaller = data_cleanup(big_df_smaller, column_to_modify, substring_to_match, replacement_value)

# %%
# Replace Decription with '-TURN' to 'Unsafe Turns'.
column_to_modify = 'Description'
substring_to_match = '-TURN'
replacement_value = 'Unsafe Turns'
big_df_smaller = data_cleanup(big_df_smaller, column_to_modify, substring_to_match, replacement_value)

# %%
# Combine Decription with 'DRIVING OFF ROADWAY WHILE PASSING VEHICLE' and 'DRIVING MOTOR VEHICLE OFF ROADWAY WHILE PASSING VEHICLE'
column_to_modify = 'Description'
substring_to_match = 'OFF ROADWAY'
replacement_value = 'DRIVING OFF ROADWAY WHILE PASSING VEHICLE'
big_df_smaller = data_cleanup(big_df_smaller, column_to_modify, substring_to_match, replacement_value)

# %%
# Replace Decription with 'CROSSWALK' to 'Defy Crosswalk rules'.
column_to_modify = 'Description'
substring_to_match = 'CROSSWALK'
replacement_value = 'Defy Crosswalk rules'
big_df_smaller = data_cleanup(big_df_smaller, column_to_modify, substring_to_match, replacement_value)

# %%
big_df_smaller["Description"].nunique()
# Out:
# 5586

# %%
big_df_smaller["Description"].value_counts()
# Out:
# Speeding                                                                                                301842
# Registration Violation                                                                                  268130
# License Violation                                                                                       198150
# DRIVER FAILURE TO OBEY PROPERLY PLACED TRAFFIC CONTROL DEVICE INSTRUCTIONS                              148229
# Improper Stop                                                                                           113981
# Improper Equipment                                                                                      106854
# DUI                                                                                                      53300
# Using Phone                                                                                              51545
# Lane Violation                                                                                           49110
# SeatBelt - Not restrained                                                                                31893
# Obstructed View                                                                                          25293
# NEGLIGENT DRIVING VEHICLE IN CARELESS AND IMPRUDENT MANNER ENDANGERING PROPERTY, LIFE AND PERSON         24469
# Failure to Yield                                                                                         19971
# DRIVING VEH. W/O ADEQUATE REAR REG. PLATE ILLUMINATION                                                   19227
# Non-Moving Violation                                                                                     15005
# Unsafe Turns                                                                                             14606
# Uninsured Vehicle                                                                                        13057
# DRIVER ENTERING INTERSECTION AT FLASHING RED TRAFFIC SIGNAL WITHOUT STOPPING                             13033
# Failure to stop at different circumstances                                                               12802
# FAILURE TO DRIVE VEHICLE ON RIGHT HALF OF ROADWAY WHEN REQUIRED                                          12473
# Reckless Driving                                                                                         11459
# Involved in Accident                                                                                     11239
# Learners Permit                                                                                          10025
# DRIVER OF MOTOR VEHICLE FOLLOWING VEHICLE CLOSER THAN REASONABLE AND PRUDENT                              7055
# Suspended License or Registration                                                                         6916
# DRIVING WHILE LIC. SUSP. UNDER 16-203, 16-206A2 FAIL TO ATTEND DIP, 17-106, 26-204/206, 27-103            6736
# FAILURE TO DISPLAY TAB ON PLATES OF VEH. AS REQUIRED BY ADM.                                              5841
# FAILING TO SECURE CHILD UNDER AGE 8 IN CHILD SAFETY SEAT WHEN TRANSPORTING IN MOTOR VEHICLE               4873
# FAILURE OF MV OPER TO PRESENT EVIDENCE OF REQUIRED SECURITY ON REQUEST OF A LAW ENFORCEMENT OFFICER       3854
# Defy Crosswalk rules                                                                                      3731
# DRIVING OFF ROADWAY WHILE PASSING VEHICLE                                                                 3481
# FAILURE TO ATTACH VEH. REG. PLATES AT FRONT AND REAR                                                      3409
# DRIVING WRONG WAY--ONE WAY STREET                                                                         2947
# Trespassing                                                                                               2941
# FAILURE OF DRIVER TO DRIVE TO CURB UPON SIGNAL BY POLICE VEH.                                             2866
# DRIVING UNSAFE VEH. ON HWY.                                                                               2424
# OWNER FAILURE TO MAINTAIN REQUIRED SECURITY FOR VEH. DURING REG. PERIOD                                   2382
# DRIVING A MOTOR VEH WITHOUT A VALID MEDICAL EXAMINERS CERTIFICATE IN POSSESSION                           2309
# FAILURE TO NOTIFY ADM. OF ADDRESS CHANGE WITHIN 30 DAYS                                                   2292
# DRIVING A VEHICLE WHILE A REMOVABLE WINDSHIELD PLACARD IS HANGING FROM THE INSIDE REARVIEW MIRROR         1907
# DISPLAYING REG. PLATE ISSUED FOR OTHER VEHICLE                                                            1829
# UNSAFE BACKING OF MOTOR VEH.                                                                              1722
# CAUSING STANDING VEH. TO OBSTRUCT FREE VEH. PASSAGE OF ROADWAY                                            1690
# FAILURE TO DRIVE RIGHT OF CENTER                                                                          1545
# FAILURE OF MV OPER. DRIVING ON HWY TO BE IN POSS.OF, CARRY IN MV EVID. OF REQ'D SECURITY FOR MV           1229
# DRIVER FAILURE TO AVOID PROJECTING GLARING LIGHT WITHIN 500 FEET OF APPROACHING VEH. DRIVER               1154
# MOTOR VEH. EQUIPPED WITH UNLAWFULLY MODIFIED EXHAUST SYSTEM                                               1049
# FOLLOWING VEH. TOO CLOSELY                                                                                1035
# DRIVER FAILURE TO REDUCE LIGHT DISTRIBUTION WHEN WITHIN 300 FEET OF APPROACHING VEH. FROM REAR             985
# FAILING TO DISPLAY PROPER VEHICLE I.D.                                                                     985
# DRIVER SPINNING WHEELS                                                                                     951
# AGGRESSIVE DRIVING                                                                                         900
# VEH. HWY. OPERATION WITH INADEQUATE REAR RED LIGHT REFLECTOR                                               872
# MODIFYING EXHAUST SYSTEM ON MOTOR VEH. CAUSING EXCESSIVE NOISE EMISSION                                    844
# FAILURE OF INDIVIDUAL DRIVING ON HWY. TO HAVE LIC.WITH HIM                                                 839
# OPERATING MOTOR VEHICLE WITHOUT PROPER REQUIRED EMEMERGENCY EQUIPMENT ON POWER UNIT                        816
# DRIVER USE OF MOTOR VEH. HORN ON HWY. WHEN NOT REASONABLY NECESSARY FOR SAFETY                             716
# VIOLATING LIC. RESTRICTION                                                                                 710
# FAILURE NOTIFY ADM. ADDRESS CHANGE                                                                         704
# OPERATING A M/V W/O PROPER REQUIRED EMERGENCY ROADSIDE WARNING DEVICES                                     689
# DRIVING ON LEFT SIDE OF ROADWAY IN POSTED NO PASSING ZONE MARKED BY PAVEMENT STRIPING                      684
# LEAVING UNATTENDED VEH. W/O STOPPING ENGINE, LOCKING IGNITION, REMOVING KEY & SETTING BRAKE                659
# UNSAFE PASSING TO RIGHT OF OVERTAKEN VEH.                                                                  653
# DISPLAYING  REG. PLATE ISSUED FOR OTHER VEHICLE                                                            626
# FAILURE OF VEH. DRIVER TO CARRY CURRENT REG. CARD                                                          614
# FALSIFYING/ATTEMPT FALSIFY WITH FRAUDULENT INTENT OFFICIAL DOCUMENT/PLATE ISSUED BY AD.                    607
# OWNER KNOWINGLY PERMITTING MOTOR VEH. TO BE DRIVEN ON HWY. BY UNAUTHORIZED PERSON                          602
# VEH. DRIVER GIVING FALSE AND FICTITIOUS NAME TO UNIFORMED POLICE                                           580
# DRIVER CONSUMING ALCOHOLIC BEVERAGE IN PASSENGER AREA OF MOTOR VEHICLE ON HIGHWAY                          571
# PASSING IN NO PASSING ZONE                                                                                 566
# EMERGENCY BRAKING SYSTEM NOT OPERATING PROPERLY                                                            533
# FAILURE OF DRIVER TO DRIVE TO CURB UPON SIGNAL BY  POLICE VEH.                                             525
# IMPROPER PASSING OF OVERTAKEN VEHICLE                                                                      524
# OPERATING MOTOR VEHICLE WITH INADEQUATE TIRES ON OTHER THAN STEERING AXLE                                  523
# DRIVING ON HWY. WITH OBJ/MATERIAL/OBSTRUCT HANGINGFROM REARVIEW MIRROR INTERFERING W/CLEAR VIEW            519
# VIOLATING PROVISIONAL LIC. RESTRICTION                                                                     462
# ATTEMPT BY DRIVER TO ELUDE UNIFORMED POLICE BY FAILING TO STOP                                             458
# POSSESSING REVOKED LIC.                                                                                    456
# STOPPING VEH. IN INTERSECTION                                                                              446
# DRIVING LEFT OF ROADWAY CENTER IN OVERTAKING AND PASSING WHEN UNSAFE                                       446
# DRIVING VEH. WHILE IMPAIRED BY A CONTROLLED DANGEROUS SUBSTANCE                                            444
# PERSON DRIVING MOTOR VEH. ON HWY. W/O TIRES IN SAFE OPERATING CONDITION AS REQUIRED BY ADM.                418
# ATTEMPT BY DRIVER TO ELUDE POLICE IN OFFICIAL POLICE VEHICLE BY FAILING TO STOP                            418
# DRIVING VEH. NOT EQUIPPED WITH AN IGNITION INTERLOCK AS REQUIRED BY PROGRAM                                410
# DRIVING MOTOR VEH. ON HWY. WEARING EARPLUGS IN BOTH EARS                                                   406
# DRIVER FAIL TO MAKE REQUIRED STOP AT PAVEMENT MARK                                                         406
# FAIL TO DISPLAY REG. CARD ON DEMAND                                                                        385
# USING DEVICE ON MOTOR VEH. EXHAUST EXTENSION CAUSING EXCESSIVE NOISE                                       374
# UNLAWFUL USE OF HISTORIC PASSENGER VEH. FOR GENERAL DAILY TRANSPORTATION                                   372
# MOTOR VEH. EQUIPPED WITH UNLAWFULLY MODIFIED EXHAUST SYSTEM, NOISE ABATEMENT DEVICE                        370
# DRIVING W/O CURRENT TAGS                                                                                   367
# STOPPING VEH. WHERE PROHIBITED BY OFFICIAL SIGN                                                            361
# DRIVING MOTOR VEHICLE WITH ALCOHOL IN BLOOD IN VIOLATION OF RESTRICTION                                    353
# DRIVER FAILURE TO EXERCISE DUE CARE TO AVOID PEDESTRIAN COLLISION                                          348
# FAILURE TO REMAIN STOPPED FOR STOPPED SCHOOL VEH. OPERATING ALTERNATELY FLASHING RED LIGHTS                345
# FAILURE OF DRIVER TO DRIVE TO CURB UPON SIGNAL BY EMERGENCY, POLICE VEH.                                   337
# FAILURE TO EQUIP MOTOR VEH. WITH ADEQUATE VISION OUTSIDE MIRROR                                            335
# DRIVING A RENTED MOTOR VEHICLE IN VIOLATION OF RENTAL AGREEMENT                                            331
# DRIVING WHILE IMPAIRED BY A CONTROLLED DANGEROUS SUBSTANCE                                                 327
# IMPROPER DISPLAY OF CURRENT AND VINTAGE REG. PLATES                                                        315
# DRIVING MOTOR VEH. IN MANNER INTENDED TO CAUSE EXCESSIVE NOISE                                             298
# WILLFULLY DISOBEYING LAWFUL ORDER AND DIRECTION OF POLICE OFFICER                                          284
# ATTEMPT BY DRIVER TO ELUDE UNIFORMED POLICE BY FLEEING ON FOOT                                             283
# DISPLAYING / PERMITTING TO BE DISPLAYED REG. PLATE ISSUED FOR OTHER VEHICLE / TO OTHER PERSON              280
# OPERATING MOTOR VEHICLE WITH FLAT TIRE                                                                     279
# DRIVING UNSECURED LOADED VEH.                                                                              268
# NEGLIGENT DRIVING                                                                                          266
# DRIVING VEH. ON SIDEWALK AND SIDEWALK AREA WHERE PROHIBITED                                                255
# PERSON DRIVING REG. MOTOR VEH. ON HWY. W/O REQUIRED SAFETY GLASS EQUIPMENT                                 255
# KNOWINGLY USING FALSIFIED VEH. REG. PLATE                                                                  252
# FAILURE OF MV OPER. DRIVING ON HWY TO CARRY IN MV EVID. OF REQ'D SECURITY FOR MV                           244
# OPERATING CMV WITHOUT PROOF OF PERIODIC INSPECTION                                                         242
# FAILURE TO PROPERLY MAINTAIN AND FASTEN VEH. REG. PLATE IN VISIBLE POSITION                                241
# FAIL TO MAINT. LEG REG PLATE FROM COVERS                                                                   240
# DRIVING, ATTEMPTING TO DRIVE) MOTOR VEHICLE WITH ALCOHOL IN BLOOD IN VIOLATION OF RESTRICTION              232
# DRIVING, CAUSING TO BE DRIVEN, KNOWINGLY PERMIT- ING TO BE DRIVEN UNSAFE VEH. ON HWY.                      223
# DRIVER FAILING TO PREVENT AGAINST LOSS OF LOAD                                                             219
# FAILURE TO DRIVE ON RIGHT HAND ROADWAY OF DIVIDED HWY                                                      215
# PERSON WITH MD REG. VEHICLE FAILING TO TRANSPORT CHILD WEIGHING 40 LBS OR LESS IN CHILD SAFETY SEAT        214
# STOPPING VEH. ON HWY. OUTSIDE BUSINESS & RESIDENTIAL DISTRICT                                              213
# KNOWINGLY PERMITTING VEH. UNDER PERSON'S CONTROL TO BE DRIVEN ON HWY. BY UNAUTHORIZED PERSON               212
# DIRECTING AND PERMITTING HWY. VEH. OPERATION CONTRARY TO LAW                                               211
# SUSP                                                                                                       211
# FAILURE OF DRIVER APPROACHING NONFUNCT. TRAFFIC CONTRL SIGNAL AT INTERSECTION TO STOP AT STOP LINE         208
# THROWING ANY REFUSEON HWY.                                                                                 204
# DRIVING VEH WHILE SO FAR IMPAIRED BY DRUGS CANNOT DRIVE SAFELY                                             202
# INSTALLATION OF BATTERY IMPROPER                                                                           190
# ATTEMPT BY DRIVER TO ELUDE POLICE IN OFFICIAL POLICE VEH. BY FLEEING ON FOOT                               182
# UNAUTHORIZED DISPLAY AND USE OF REG. PLATE                                                                 179
# MODIFYING EXHAUST SYSTEM, NOISE ABATEMENT DEVICE ON MOTOR VEH. CAUSING EXCESSIVE NOISE EMISSION            175
# STANDING VEH. WHERE PROHIBITED BY OFFICIAL SIGN                                                            168
# POSSESSING FICTITIOUS LIC.                                                                                 166
# OPERATING MOTOR VEHICLE WITH UNDER-INFLATED TIRE                                                           165
# DRIVING MOTOR VEHICLE WHEN NOT ABLE TO COMPLY WITH ENGLISH SPEAKING REQUIREMENTS                           163
# ATTEMPT BY DRIVER TO ELUDE UNIFORMED POLICE BY MEANS OTHER THAN FAIL TO STOP AND FLEEING ON FOOT           159
# DISPLAY REVOKED LIC.                                                                                       158
# DRIVING ON MEDIAN STRIP ON DIVIDED HWY.                                                                    158
# USING DEVICE ON MOTOR VEH. EXHAUST, TAIL PIPE EXTENSION CAUSING EXCESSIVE NOISE                            157
# DRIVING MOTOR VEH. ON HWY. WEARING HEADSET OVER EARS                                                       157
# OPER SOUND AMPLIFICATIONSYSTEM FROM VEH THAT CAN BE HEARD FROM 50' OR MORE                                 156
# FAILURE TO DESTROY TEMP. REG. PLATES UPON EXPIRATION OF TEMP. REG.                                         149
# MATERIALLY ALTERING, CHANGING VEH. EQUIPMENT AFTER INSPECTION, REPAIR ORDER CERT. ISSUED.                  149
# USING FLASHING LIGHTING ON UNAUTHORIZED VEH.                                                               148
# OPERATING MOTOR VEHICLE WITH INADEQUATE WINDSHIELD WIPERS                                                  146
# FAILURE OF MV OPER. DRIVING ON HWY TO BE IN POSS.OF EVID. OF REQ'D SECURITY FOR MV                         143
# PERSON DRIVING MOTOR VEH. ON HWY. ON REVOKED LIC. AND PRIVILEGE                                            141
# KNOWINGLY HOLDING FALSIFIED VEH. REG. PLATE                                                                136
# WILLFULLY DISOBEYING DIRECTION OF A POLICE OFFICER                                                         131
# OPERATING A M/V WITH INADEQUATE TIRES ON OTHER THAN STEERING AXLE                                          131
# OPERATING MOTOR VEHICLE WITHOUT PROPER REQUIRED EMERGENCY EQUIPMENT ON POWER UNIT                          129
# UNLAWFUL USE VEHICLE REGISTERED AS A HISTORIC MOTOR VEHICLE                                                128
# DRIVING  UNSAFE VEH. ON HWY.                                                                               124
# WILLFULLY DISOBEYING LAWFUL ORDER, DIRECTION OF A POLICE OFFICER                                           121
# DRIVING VEH. WHILE SO FAR IMPAIRED BY DRUGS CANNOT DRIVE SAFELY                                            120
# IMPROPER NUMBER OF TIEDOWNS USED FOR LENGTH OF CARGO                                                       118
# UNAUTHORIZED USE OF CLASS 1A DEALER REG. PLATE                                                             118
# DRIVING ON HWY. WITH OBJ/MATERIAL/OBSTRUCT IN/ON VEH. INTERFERING WITH CLEAR VIEW                          116
# PROHIBITED USE OF FLASHING LIGHT                                                                           116
# DRIVING VEH W/ TV-TYPE RECEIVING EQUIP, VIDEO DISPEQUIP THAT IS ON AND VISIBLE TO THE DRIVER ON HWY        115
# VEH. HWY. OPERATION WITH INADEQUATE REAR RED COLOR REFLECTOR                                               115
# DISPLAYING REG. PLATE ISSUED FOR OTHER VEHICLE / TO OTHER PERSON                                           114
# HOLDER OF NON-COMMERCIAL CLASS C DR. LIC. DRIVE ON HWY M/V OF THE TYPE AUTH BY LIC                         113
# ATTEMPT BY DRIV TO ELUDE POLICE IN OFFCAL POLICE VEH. BY MEANS OTHER THAN FAIL STOP & FLEE BY FOOT         111
# FAILURE TO EQUIP MOTOR VEH. WITH ADEQUATE VISION REAR VIEW MIRROR                                          110
# OPERATING VEH. ON HWY. WITH ALTERED & DANGEROUS BUMPER OR SUSPENSION                                       110
# DRIVING MOTOR VEH. NOT IN ACCORDW/ EQUIP., PERF, & OTHER TECH STANDARDS                                    110
# DRIVER PERMITTING PERSON TO OCCUPY AREA OF VEHICLEPRIMARILY INTENDED TO CARRY CARGO                        110
# THROWING ANY REFUSE ON HWY.                                                                                108
# PERSON KNOWINGLY INSERTING FALSE INFORMATION ON TEMP. REG. PLATE                                           107
# FAIL VEH DRIVER IN ACC.TO RPT. ATTENDED VEH. DAMAGE TO NEAREST POLICE                                      106
# DRIVING VEH. W/O OWNER'S CONSENT WITH INTENT TO DEPRIVE OWNER                                              106
# OPERATING MOTOR VEHICLE WITH INADEQUATE STEERING AXLES TIRE                                                104
# PROVISIONAL DRIVER UNDER 18 DRIVING M/V W/PASSENGER UNDER 18                                               103
# TAKING VEH. W/O OWNER'S CONSENT WITH INTENT TO DEPRIVE OWNER                                                99
# MOTOR CARRIER FAIL TO CORRECT DEFECTS NOTED ON INSPECTION REPORT                                            98
# OPERATING MOTOR VEHICLE WITHOUT ADEQUATE HORN                                                               97
# FRAUDULENT POSSESSION OF VEH OWNERSHIP REG. PLATE                                                           96
# LEAVE THE ROADWAY FOR THE PURPOSE OF AVOIDING TRAFFIC CONTROL DEVICE                                        95
# PERSON DRIVING MOTOR VEH. ON HWY., PUBLIC USE PROPERTY ON REVOKED LIC. AND PRIVILEGE                        94
# DRIVING WHILE SUSP. UNDER 16-203, 16-206A2 FAIL TO ATTEND DIP, 17-106, 26-204/206, 27-103                   94
# KNOWINGLY USING FALSIFIED VEH. DOCUMENT, REG. PLATE                                                         93
# DISPLAYING / PERMITTING TO BE DISPLAYED REG. PLATE ISSUED FOR OTHER VEHICLE                                 93
# DOING FORBIDDEN ACT PERTAINING TO DRIVER'S LIC.                                                             92
# MATERIALLY ALTERING VEH. EQUIPMENT AFTER REPAIR ORDER CERT. ISSUED.                                         91
# CARRIER FAILING TO COMPLY WITH RULES IN PART 396                                                            91
# ALLOWING UNREG. VEH. TO BE DRIVEN ON HWY.                                                                   91
# WILLFULLY DISOBEYING LAWFUL ORDER OF A POLICE OFFICER                                                       90
# DRIVING WHILE LIC. SUSP. UNDER 16-203                                                                       90
# OWNER OF MOTOR SCOOTER FAILURE TO DISPLAYDECAL ON VEHICLE AS PRESCRIBED BY MVA                              89
# FAILURE OF VEH. DRIVER TO  CARRY CURRENT REG. CARD                                                          88
# USING DEVICE ON MOTOR VEH. TAIL PIPE EXTENSION CAUSING EXCESSIVE NOISE                                      88
# FAILURE OF MV OPER. DRIVING ON HWY TO  CARRY IN MV EVID. OF REQ'D SECURITY FOR MV                           88
# FAILURE OF VEH. DRIVER TO DISPLAY CURRENT REG. PLATES                                                       87
# DRIVING WHILE LIC. SUSP. UNDER 16-206A2 FAIL TO ATTEND DIP                                                  86
# VEH. HWY. OPERATION WITH INADEQUATE SIDE LIGHT                                                              86
# DRIVING MOTOR VEH. ON HWY WEARING EARPLUGS IN BOTH EARS                                                     85
# OPERATING MOTOR VEHICLE WITH MISSING WHEEL FASTENERS                                                        84
# DRIVER FAILING TO SECURE LOAD TO PREVENT LOSS                                                               84
# FAIL TO MAINT. LEG REG PLATE FROM FOREIGN MATERIALS                                                         84
# OWNER FAILURE TO APPLY FOR TITLE CERT. FOR INSTATE VEH.                                                     83
# OWNER FAILURE TO APPLY TO ADM. FOR REG OF VEH. SUBJECT TO REG.                                              81
# CARRYING LOOSE MATERIAL LOADED TO WITHIN SIX INCHES OF TOP OF ENCLOSURE W/O COVERING LOAD                   81
# UNLAWFUL USE OF HISTORIC PASSENGER VEH FOR GENERAL DAILY TRANSPORTATION                                     80
# STANDING VEH. IN INTERSECTION                                                                               79
# DRIVING VEH. ON HWY. WHILE DISPLAYING FLASHING LIGHT                                                        76
# DRIVING WHILE LIC. SUSP. UNDER 26-204                                                                       75
# FAIL TO MAINT. LEG REG PLATE FROM  COVERS                                                                   74
# FAIL TO MAINT. LEG REG PLATE FROM FOREIGN MATERIALS, COVERS                                                 73
# OPERATOR OF MOTOR SCOOTER FAILURE TO CARRY REQUIRED SECURITY                                                73
# FAIL TO TRANSPORT CHILD UNDER AGE 16 IN CHILD SAFTEY SEAT PER INSTRUCTIONS                                  73
# TURNING OFF VEH. LIGHTS TO AVOID ID                                                                         72
# DRIVING VEH. IN RACE ON HWY.                                                                                72
# FAILURE TO KEEP REQUIRED MOTOR VEH. RENTAL RECORDS                                                          71
# MOTOR VEH. NOT EQUIPPED WITH EXHAUST MUFFLER SYSTEM                                                         71
# OPERATING MOTOR VEHICLE WITH INADEQUATE STEERING AXLES TIRES                                                71
# FAILURE OF DRIVER TO DRIVE TO CURB UPON SIGNAL BY EMERGENCY VEH.                                            70
# DISPLAYING REG. PLATE ISSUED TO OTHER PERSON                                                                69
# USE OF INCORRECT COLOR IN LIGHTING DEVICES MOUNTED ON REAR OF VEHICLE                                       69
# DRIVING, ATTEMPTING TO DRIVE MOTOR VEHICLE WITH ALCOHOL IN BLOOD IN VIOLATION OF RESTRICTION                68
# DRIVING MOTOR VEH NOT IN ACCORDW/ EQUIP., PERF, & OTHER TECH STANDARDS                                      68
# OWNER FAILURE TO SURENDER REG. EVIDENCES WITHIN 48 HOURS AFTER NOTICE OF SUSPENSION                         66
# UNLAWFUL POSSESSION OF EXPIRED VEH. REG. PLATES                                                             66
# FAILURE OF DR. APPR. NONFUNCT. TRAF. CONTRL SIGNALAT INTERSECTION TO STOP BEFORE ENTERING INTERSECT.        65
# PARTS NOT SPECIFICALLY PROVIDED FOR NOT IN SAFE OPERATING CONDITION                                         64
# DRIVING VEH W/ VIDEO DISP EQUIP THAT IS ON AND VISIBLE TO THE DRIVER ON HWY                                 62
# DRIVER STARTING VEH. FROM STOPPED POSITION WHEN UNSAFE                                                      62
# DRIVER FAILURE TO USE MULTIPLE-BEAM ROAD LIGHTING EQUIPMENT AT LEVEL REQUIRED FOR SAFE DRIVING              62
# HWY. DRIVEN VEH. EQUIPPED WITH TIRES WITH PROHIBITED PROJECTING PROTUBERANCE                                60
# FAIL VEH DRIVER IN ACC.TO RPT. PROP DAMAGE TO NEAREST POLICE                                                60
# FAIL TO MAINT. LEG REG PLATE FROM FOREIGN MATERIALS, COVERS SECONDARY FOR FRAME/BORDER                      58
# MOTOR VEH. OWNER REPLACING VEH. BROKEN WINDSHIELD GLASS WITH OTHER THAN SAFETY GLASS                        57
# DRIVING WHILE LIC. SUSP. UNDER 16-203, 16-206A2, 17-106, 26-204/206, 27-103                                 56
# DRIVING, ATTEMPTING TO DRIVE VEH. NOT EQUIPPED WITH AN IGNITION INTERLOCK AS REQUIRED BY PROGRAM            55
# DISPLAYING REG. PLATE ISSUED FOR OTHER VEH.                                                                 55
# OPER. MOTOR VEH. WITH OCCUPANT UNDER 16 NOT RESTRAINED BY CHILD SAFETY SEAT                                 55
# DRIVING VEH VIDEO DISPEQUIP THAT IS ON AND VISIBLE TO THE DRIVER ON HWY                                     55
# DISPLAYING  REG. PLATE ISSUED FOR OTHER VEHICLE / TO OTHER PERSON                                           55
# THROWING ANY REFUSEON HWY                                                                                   55
# PERMITTING UNAUTHORIZED PERSON TO DRIVE RENTED MOTOR VEHICLE IN VIOLATION OF RENTAL AGREEMENT               54
# DRIVING VEH. WHILE IMPAIRED BY CONTROLLED DANGEROUS SUBSTANCE                                               54
# DRIVING VEH W/ VIDEO DISPEQUIP THAT IS ON AND VISIBLE TO THE DRIVER ON HWY                                  53
# DRIVE VEH. REQ. CLASS C LIC ON HWY W/O CLASS C LIC                                                          53
# THROWING, DUMPING, DISCHARGE, DEPOSIT ANY REFUSEON HWY., PUBLIC BRIDGE, PUBLIC WATERS                       52
# DRIVER OPERATING MV WHEN DRIVER NOT QUALIFIED TO DO SO                                                      52
# DRIVING MOTOR VEH. ON HWY., PUBLICLY USED PRIVATE PLACE WEARING EARPLUGS IN BOTH EARS                       52
# FAILURE OF MV OPER. DRIVING ON HWY TO BE IN POSS.OF, EVID. OF REQ'D SECURITY FOR MV                         51
# DISPLAY FICTITIOUS LIC.                                                                                     51
# TAGS                                                                                                        51
# DRIVING, UNSAFE VEH. ON HWY.                                                                                51
# OPERATING MOTOR VEHICLE WITH INADEQUATE STEERING AXLES TIRE/S/                                              50
# DRIVING ON UNOPENED ROADWAY                                                                                 50
# FAIL VEH DRIVER IN ACC.TO RPT ATTENDED VEH. DAMAGE TO NEAREST POLICE                                        50
# UNLAWFUL USE OF HISTORIC TRUCK FOR GENERAL DAILY TRANSPORTATION                                             50
# DRIVER PASSING MOVING POLICE VEH. USING SIGNALS                                                             49
# POSSESSING CANCELLED LIC.                                                                                   48
# PERSON DRIVING ON HWY. VEH. WITH VISIBLE BLUE DEVICE                                                        48
# UNLAWFUL USE OF HISTORIC PASSENGER VEH., MOTORCYCE OR TRUCK FOR GENERAL DAILY TRANSPORTATION                48
# FAILURE TO EQUIP MOTORCYCLE WITH TWO REAR VIEW MIRRORS                                                      48
# OPERATOR OF MOPED, MOTOR SCOOTER FAILURE TO CARRY REQUIRED SECURITY                                         47
# THROWING ANY REFUSE ON HWY                                                                                  47
# KNOWINGLY PERMITTING UNAUTHORIZED USE OF REG. PLATE                                                         46
# FAIL VEH DRIVER IN ACC.TO RPT.ATTENDED VEH. DAMAGE TO NEAREST POLICE                                        46
# INDIVIDUAL OPERATING ON MOTORCYCLE W/O WEARING REQUIRED HEADGEAR PROTECTION                                 46
# MATERIALLY CHANGING VEH. EQUIPMENT AFTER REPAIR ORDER CERT. ISSUED.                                         45
# UNLAWFUL USE OF HISTORIC PASSENGER VEH., MOTORCYCE, TRUCK FOR GENERAL DAILY TRANSPORTATION                  45
# DRIVING MOTOR VEH. IN MANNER INTENDED TO CAUSE SKIDDING                                                     45
# OPERATION OF EXTENDED REAR LOAD CARRYING VEH. W/O REQUIRED RED FLAGS DISPLAY                                45
# POSSESSING FRAUDULENTLY ALTERED LIC.                                                                        45
# FAILURE TO PROVIDE TRUTHFULL IDENTIFICATION                                                                 44
# FAILING TO PERFORM REQUIRED ACT PERTAINING TO DRIVER'S LIC.                                                 44
# CARD                                                                                                        44
# KNOWINGLY USING FALSIFIED VEH.  REG. PLATE                                                                  44
# DRIVING VEH. WITH PASSENGER OVERLOAD OBSTRUCTING DRIVER'S VIEW                                              44
# FRAUDULENT POSSESSION OF VEH REG. PLATE                                                                     43
# FAILURE TO SURRENDER RECOVERED ORIGINAL AFTER ISSUANCE OF DUPLICATE                                         42
# OPERATE MOTORCYCLE W/O EYE PROTECTION                                                                       42
# FAILURE TO ATTACH TEMP. REG. PLATE TO REAR OF VEH.                                                          42
# DRIVER PASSING MOVING EMERGENCY VEH. USING SIGNALS                                                          41
# PERSON OCCUPYING AREA OFVEHICLE PRIMARILY INTENDEDTO CARRY CARGO                                            41
# STOPPING ON AUTHORITY HIGHWAY WHEN PROHIBITED                                                               41
# DRIVING WHILE LIC. SUSP. UNDER 26-204/206                                                                   41
# DRIVER FAIL TO MAKE REQUIRED STOP AT  PAVEMENT MARK                                                         41
# FAIL TO MAINT. LEG REG PLATE FROM FOREIGN MATERIALS, COVERS OR FRAME/BORDER                                 40
# INDIVIDUAL OPERATING MOTORCYCLE W/O WEARING REQUIRED HEADGEAR PROTECTION                                    40
# KNOWINGLY USING FALSIFIED VEH. DOCUMENT                                                                     40
# FAILURE TO SECURE ROLL-ON/OFF/HOOK-LIFT CONTAINERS BY PRODUCT SPECIFIC RULES                                40
# IND. OPERATING ON MOTOR SCOOTER W/O WEARING REQUIRED HEADGEAR PROTECTION                                    39
# DRIVING WHILE SUSP. UNDER 26-204/206                                                                        39
# FAILURE OF DRIVER TO DRIVE TO CURB UPON SIGNAL BY POLICE VEH                                                39
# OWNER OF MOTOR SCOOTER, MOPED FAILURE TO DISPLAYDECAL ON VEHICLE AS PRESCRIBED BY MVA                       39
# OWNER KNOWINGLY PERMITTING VEH. TO BE DRIVEN ON HWY. W/O REG. CARD                                          39
# DRIVING WHILE SUSP. UNDER 17-106                                                                            38
# DRIVING WHILE SUSP. UNDER 27-103                                                                            38
# DRIVER FAIL TO EXERCISE CAUTION AT INTERSECTION WITH FLASHING YELLOW SIGNAL                                 38
# FAILURE TO OBEY LAWFUL SIGN AT AUTHORITY HIGHWAY                                                            37
# OPER. M/V WITH OCCUPANT UNDER AGE 16 NOT RESTRAINED BY CHILD SAFETY SEAT                                    37
# HOLDER OF NON-COMMERCIAL CLASS C DR. LIC. DRIVE, ATTEMPT TO DR. ON HWY M/V OF THE TYPE AUTH BY LIC          37
# MOTOR VEH. EQUIPPED WITH UNLAWFULLY MODIFIED NOISE ABATEMENT DEVICE                                         37
# TRANSP. CHILD UNDER AGE 16 AND OVER 40 LBS W/O SAFETY SEAT OR BELT                                          37
# ENDANGERING HEALTH, SAFETY, WELFARE OF DOG BY LEAVING DOG UNATTENDED IN MOTOR VEHICLE                       36
# VEH. ENTERING INTERSECTION OCCUPIED BY FUNERAL PROCESSION                                                   36
# FAIL APPLY W/IN 48 HOURS FOR REPLACEMENT OF AFFIX-ED CURRENT REG.PLATE AFTER DAMAGE                         36
# OPERATING A COMMERCIAL MOTOR VEHICLE CMV W/O A CDL WHEN REQUIRED                                            36
# FRAUDULENTLY APPLYING FOR VEH. REG.                                                                         35
# KNOWINGLY HOLDING FALSIFIED VEH. DOCUMENT                                                                   35
# DRIVING WHILE LIC. SUSP. UNDER 16-203, 16-206A2 FAIL TO ATTEND DIP, 17-106, 26-204/206, OR 27-103           35
# OPER,PERMIT THE OPERATION OF SOUND AMPLIFICATIONSYSTEM FROM VEH THAT CAN BE HEARD FROM 50' OR MORE          34
# DRIVING MOTOR VEHICLE WHEN NOT QUALIFIED TO DO SO                                                           34
# PERSON DISPLAYING LIC. NOT ISSUED TO HIM                                                                    34
# FAILURE TO NOTIFY ADM. OF NAME CHANGE WITH 30 DAYS                                                          34
# DRIVING WHILE LIC. SUSP. UNDER 16-203, 16-206A2 FAIL TO ATTEND DIP, 17-106, 26-204/206, 27-103)             34
# FAIL TO PLACE & PROPERLY DISPLAY TEMP. REG. PLATE AFTER CURRENT REG. PLATE DAMAGED, MADE ILLEGIBLE          34
# SUSP REG                                                                                                    34
# FAILURE OF VEH. DRIVER TO FURNISH REQ'D WRITTEN IDINFO.ON UNATTENEDED DAMAGED VEH.                          34
# OPERATOR OF MOPED FAILURE TO CARRY REQUIRED SECURITY                                                        34
# FAILING TO SECURE CHILD UNDER AGE OF 8 IN CHILD SAFETY SEAT WHEN TRANSPORTING IN MOTOR VEHICLE              33
# FAIL TO PLACE & PROPERLY DISPLAY TEMP. REG. PLATE AFTER CURRENT REG. PLATE MADE ILLEGIBLE                   33
# FAILURE TO MAKE REQUIRED STOP AT PAVEMENT MARK                                                              33
# DISPLAYING REG. PLATE ISSUED FOR OTHER VEHICLE.                                                             32
# FAILURE TO APPLY FOR UNAFFIXED TABS TO REPLACE DAMAGED TABS                                                 32
# DRIVING VEH. ON HWY. WITH CANCELLED REG.                                                                    32
# WILLFULLY DISOBEYING  DIRECTION OF A POLICE OFFICER                                                         32
# DRIVING MOTOR VEH. ON HWY., PUBLICLY USE PRIVATE PLACE WEARING HEADSET OVER EARS                            32
# UNLAWFUL USE OF HISTORIC PASSENGER VEH., FOR GENERAL DAILY TRANSPORTATION                                   31
# FAIL VEH DRIVER IN ACC.TO RPT PROP DAMAGE TO NEAREST POLICE                                                 31
# CARGO MUST BE FIRMLY SECURED AND IMMOBILIZED                                                                31
# STOPPING VEH. ON SIDEWALK                                                                                   31
# FAILURE TO FULLY ENCLOSE BED OF VEHICLE CARRYING LOOSE MATERIAL                                             31
# FAIL TO MAINT. LEG REG PLATE FROM SECONDARY FOR FRAME/BORDER                                                31
# PERMITTING TO BE DISPLAYED REG. PLATE ISSUED FOR OTHER VEHICLE                                              31
# DRIVING VEH VIDEO DISP EQUIP THAT IS ON AND VISIBLE TO THE DRIVER ON HWY                                    30
# DRIVING VEH. IN RACE ON HWY                                                                                 30
# FAILURE OF VEH. DRIVER TO FURNISH REQ'D WRITTEN IDINFO. ON UNATTENEDED DAMAGED VEH.                         30
# DRIVING MOTOR VEH. ON HWY WEARING HEADSET OVER EARS                                                         30
# MOTOR VEH. EQUIPPED WITH UNLAWFULLY MODIFIED EXHAUST SYSTEM,                                                30
# OPER SOUND AMPLIFICATION SYSTEM FROM VEH THAT CAN BE HEARD FROM 50' OR MORE                                 30
# PERSON DRIVING MOTOR VEH. ON HWY ON REVOKED LIC. AND PRIVILEGE                                              30
# FRAUDULENT POSSESSION OF VEH ID PLATES                                                                      29
# ATTACHING UNAUTHORIZED VEH. REG. PLATE WITH INTENTTO MISREPRESENT VEH. ID                                   29
# USING DEVICE ON MOTOR VEH. EXHAUST CAUSING EXCESSIVE NOISE                                                  29
# DRIVING VEH. WITH UNAUTHORIZED BLINKING LIGHTS                                                              29
# DRIVING UNSAFE VEH. ON HWY                                                                                  29
# IND. OPERATING,RIDING ON MOPED,MOTOR SCOOTER W/O WEARING REQUIRED HEADGEAR PROTECTION                       29
# DRIVER BACKING MOTOR VEH. ON SHOULDER OF CONTROLLED ACCESS HWY.                                             29
# ROADWAY USE OF VEH. HIGH INTENSITY LIGHT IMPROPER-LY DIRECTED AT ROADWAY                                    29
# DRIVING MOTOR VEH., AUTOCYCLE, LSV NOT IN ACCORDW/ EQUIP., PERF, & OTHER TECH STANDARDS                     28
# FAILURE TO MAINTAIN WINDSHIELD WIPERS IN GOOD WORKING ORDER                                                 28
# VEHICLE CARRYING A LOAD OF LOOSE MATERIAL WITHOUT CANVAS OR OTHER APPROVED COVER                            28
# PEDESTRIAN UNSAFELY CROSSING IN PATH OF VEH.                                                                28
# STOPPING VEH. ON HWY. WITH LESS THAN 200 FT. VISIBILITY                                                     28
# DRIVINGUNSAFE VEH. ON HWY.                                                                                  27
# DISPLAYING REG. PLATES ISSUED FOR OTHER VEH.                                                                27
# USE OF CLASS 5 TRANSPORTER REG. PLATE OTHER THAN AS PERMITTED IN 13-625                                     27
# INADEQUATE EXHAUST SYSTEM                                                                                   27
# KNOWINGLY HOLDING FALSIFIED VEH. DOCUMENT, REG. PLATE                                                       27
# PERSON DRIVING MOTOR VEH. ON HWY., PUBLIC USE PROPERTY ON CANCELLED LIC. AND PRIVILEGE                      27
# OWNER FAILURE TO EXECUTE SECURITY INTEREST INFO. ON VEH. TITLE CERT.                                        27
# OWNER OF MOTOR SCOOTER FAILURE TO DISPLAY DECAL ON VEHICLE AS PRESCRIBED BY MVA                             27
# VEH. HWY. OPERATION WITH INADEQUATE  REAR RED COLOR REFLECTOR                                               27
# FAILURE OF TRANSFEREE TO APPLY FOR AND OBTAIN NEW REG. OF VEH. BEFORE DRIVING ON HWY.                       26
# DRIVER FAILURE TO SOUND HORN WARNING TO PEDESTRIAN                                                          26
# PERSON OPERATING MOTOR SCOOTER W/O APPROVED EYE PROTECTIVE DEVICE                                           26
# PERSON DRIVING TRAILER ON HWY W/O TIRES IN SAFE OPERATING CONDITION AS REQUIRED BY ADM.                     26
# DRIVER OPERATING MOTOR VEHICLE WITHOUT PRESCRIBED EMERGENCY EQUIPMENT                                       26
# FAIL VEH DRIVER IN ACC.TO RPT.PROP DAMAGE TO NEAREST POLICE                                                 26
# DRIVING MOTOR VEH. ON HWY., WEARING EARPLUGS IN BOTH EARS                                                   26
# OPERATING MOTOR VEHICLE WITH EXTENDED LOAD WITHOUT FLAGS                                                    26
# FAIL TO OBTAIN NONRESIDENT PERMIT WITHIN REQ TIME PERIOD WHEN MAINTAIN/OCCUPY DWELL > 30 DAYS < 1 YR        26
# UNSAFE DRIVING THROUGH YIELD SIGN                                                                           25
# DRIVER BACKING MOTOR VEH. ON ROADWAY OF CONTROLLED ACCESS HWY.                                              25
# FAILURE TO REMOVE AND RETURN REG. PLATES 10 DAYS AFTER VEH. TRANSFER.                                       25
# DRIVING MOTOR VEH. ON HWY.WEARING EARPLUGS IN BOTH EARS                                                     25
# FAILURE TO ENSURE TOWED VEHICLE IS SECURELY ATTACHED TO TOWING VEHICLE BY PRIMARY CONNECTING SYSTEM         25
# FAILURE OF TRANSFEREE OF VEH. TO PROMPTLY APPLY FOR NEW TITLE CERTIFICATE                                   24
# PERSON OPERATING MOPED, MOTOR SCOOTER W/O APPROVED EYE PROTECTIVE DEVICE, WINDSCREEN                        24
# FAILURE OF VEH. DRIVER TO DISPLAY CURRENT REG. PLATES, CARRY CURRENT REG. CARD                              24
# FAILURE OF WARNING LIGHTS TO BE VISIBLE FROM NOT LESS THAN 1500 FOOT NIGHTTIME DISTANCE                     24
# FAIL APPLY W/IN 48 HOURS FOR REPLACEMENT OF AFFIX-ED CURRENT REG.PLATE AFTER THEFT                          24
# WINDOW GLAZING DAMAGED                                                                                      24
# OPERATING MOTOR VEHICLE WITH FABRIC EXPOSED THROUGH TREAD OF TIRE                                           24
# DRIVING VEHICLE DIRECTLY IN FRONT OF OVERTAKEN VEHICLE                                                      24
# MOTOR VEH. WITH LIT BACKUP LIGHT WHILE VEH. IN FORWARD MOTION                                               24
# MATERIALLY ALTERING VEH. EQUIPMENT AFTER  REPAIR ORDER CERT. ISSUED.                                        23
# FAIL TO PLACE & PROPERLY DISPLAY TEMP. REG. PLATE AFTER CURRENT REG. PLATE DAMAGED                          23
# FAILURE TO SECURE AUTOMOBILE, LIGHT TRUCK/VANS BY LOAD SPECIFIC RULES                                       23
# DRIVING WHILE LIC. SUSP. UNDER 16-203, 17-106, 26-204/206, 27-103                                           23
# OPERATING ON HWY.A MV W/O EXHAUST MECHANISM PROP EQUIP,ADJUST &OPER                                         23
# OPERATING A COMMERCIAL MOTOR VEHICLE W/O A CDL WHEN REQUIRED                                                22
# FAILURE TO PASS AROUND ROTARY TRAFFIC ISLAND TO RIGHT OF ISLAND                                             22
# DRIVER FAIL TO COMPLY WITH LOCAL LAWS                                                                       22
# REG                                                                                                         22
# COMMERICAL DRIVER FAILURE TO NOTIFY MVA WITHIN 30 DAYS OF ADDRESS CHANGE                                    22
# DRIVING VEH. ON HWY WITH DEVICE IMPROPERLY DISPLAYING WHITE LIGHT FROM REAR                                 22
# DRIVING VEH W/ TV-TYPE RECEIVING EQUIP, VIDEO DISP EQUIP THAT IS ON AND VISIBLE TO THE DRIVER ON HWY        22
# FAIL APPLY W/IN 48 HOURS FOR REPLACEMENT OF AFFIX-ED CURRENT REG.PLATE AFTER LOSS                           22
# STOPPING, VEH. ON HWY. OUTSIDE BUSINESS & RESIDENTIAL DISTRICT                                              22
# FAIL TO MAINT. LEG REG PLATE FROM SECONDARY FOR FRAME                                                       22
# VEH. OWNER KNOWINGLY PERMITTING UNLAWFUL HWY. VEH. OPERATION                                                21
# INDIVIDUAL OPERATING, RIDING ON MOTORCYCLE W/O WEARING REQUIRED HEADGEAR PROTECTION                         21
# PLATE                                                                                                       21
# DRIVING MOTOR VEHICLE WHEN NOT QUALIFIED TO DO SO/MOTOR CARRIER PERMITTING PERS NOT QUALIFIED TO DRV        21
# FAILURE TO ENSURE THAT SAFETY CHAINS ARE PROPERLY ATTACHED TO TOWED VEH. & FRAME OF TOWING VEH.             21
# FAILURE OF WARNING LIGHTS TO BE VISIBLE FROM NOT LESS THAN 1500 FEET NIGHTTIME DISTANCE                     21
# PERSON OPENING DOOR OF MOTOR VEH. ON MOVING TRAFFIC SIDE WHEN UNSAFE                                        21
# DRIVING VEH. WHILE IMPAIREDBY CONTROLLED DANGEROUS SUBSTANCE                                                21
# LEAVING STANDING VEH. ON HWY. OUTSIDE BUSINESS & RESIDENTIAL DISTRICT                                       21
# FAILURE OF VEHICLE OWNER TO NOTIFY ADM. ON REQUIRED FORM OF VEHICLE INFORMATION CHANGE                      21
# DRIVING VEH W/ TV-TYPE RECEIVING EQUIP THAT IS ON AND VISIBLE TO THE DRIVER ON HWY                          21
# UNLAWFUL USE OF HISTORIC PASS.VEH. FOR TRANSP. TO AND FROM EMPLOYMENT                                       21
# THROWING, DUMPING, DISCHARGE, DEPOSIT ANY REFUSE ON HWY., PUBLIC BRIDGE, PUBLIC WATERS                      21
# DRIVER OPERATE COMMERCIAL MV WHEN DRIVER IS DISQUALIFIED                                                    20
# FRAUDULENT POSSESSION OF VEH OWNERSHIP REG. PLATE,CARD, TITLE CERT., ID PLATES                              20
# NO UNIV JOINT,STEER GEAR BX,PITMAN AREA SHALL BE WORN FAULTY/LOOSE/NOT HAVE LOOSE,MISS MOUNT BOLT           20
# DISPLAY FRAUDULENTLY ALTERED LIC.                                                                           20
# UNLAWFUL USE OF HISTORIC PASS. VEH. FOR PRIM. TRANS. OF PASS. ON HWY.                                       20
# VEH. PASSENGER OBSTRUCTING DRIVER VIEW                                                                      20
# MODIFYING EXHAUST SYSTEM, NOISE ABATEMENT DEVICEON MOTOR VEH. CAUSING EXCESSIVE NOISE EMISSION              20
# DRIVING WHILE LIC. SUSP. UNDER 16-203, 16-206A2 FAIL TO ATTEND DIP, 17-106, 26-204/206 OR 27-103            20
# STANDING VEH. WITHIN 15 FEET FIRE HYDRANT                                                                   20
# FAILURE OF DRIVER TO DRIVE TO CURB UPON SIGNAL BY POLICE                                                    20
# PLATES                                                                                                      19
# FAILURE OF DRIVER TO STAY UPON APPROACH BY POLICE VEH. USING SIGNALS                                        19
# WINDSHIELD WASHER SYSTEM INOPERABLE                                                                         19
# FAILING TO PROPERLY DISPLAY COMPANY NAME, DBA NAME, ISSUED US DOT NUMBER                                    19
# FAILURE OF LOADED HWY. VEH. TO BE SAFELY LOADED                                                             19
# FAILURE TO KEEP REQUIRED MOTOR VEH RENTAL RECORDS                                                           19
# DROPPING INJURIOUS SUBSTANCE ON HWY                                                                         19
# PERSON DRIVING MOTOR VEH. ON HWY. ON REVOKED OUT OF STATE LIC.                                              19
# UNLAWFUL ALTERING OF MFR. INSTALLED EXHAUST EMISSION CONTROL ON VEH.                                        19
# FAIL VEH DRIVER IN ACC.TO RPT.PROP DAMAGETO NEAREST POLICE                                                  19
# FAILURE TO PROVIDE TRUTHFUL IDENTIFICATION                                                                  18
# DRIVER RECORD OF DUTY STATUS NOT CURRENT                                                                    18
# ...
# DRIVING COMMERCIAL MOTOR VEH. WHILE PRIVILEGE REVOKED IN THIS STATE                                          1
# FAILURE TO OBEY POLICE OFFICER DIRECTION TOSTOP DIESEL VEH. FOR EMISSION TEST                                1
# WILLFULLY DISOBEYING LAWFUL DIRECTION  OF A POLICE OFFICER                                                   1
# DRIVING WHILE LIC. SUSP.  17-106, 26-204/206, 27-103                                                         1
# FAIL OF VEH OPER TO REMOVE SPECIAL FUEL FROM DEL- IVERY CONTAINER WHERE NEXT DELIVERY TO BE GASOLINE         1
# DRIVING VEH. IN RACE ON HWY. USED BY PUBLIC)                                                                 1
# DRIVE VEH REQ. CLASS A LIC ON HWYW/O CLASS A LIC,                                                            1
# FAILURE TO MAINTAIN LEGIBLE REG PLATE IN VISIBLE POSITION FREE FROM FOREIGN MATERIALS, COVERS                1
# UNLAWFUL USE OF HISTORIC PASS. VEH./ TRUCK FOR PRIM. TRANS. OF PASS. & PROP. ON HWY.                         1
# STANDING) ON AUTHORITY HIGHWAY WHEN PROHIBITED                                                               1
# APPLY FOR LIC., KNOWLINGLY MAKING FALSE STATEMENT                                                            1
# FAILURE OF DRIVER TO DRIVE TO CURB UPON SIGNAL BY MARKED POLICE VEH.                                         1
# DRIVE, ATT. TO DRIVE VEH. REQ. CLASS B LIC ON HWY W/O CLASS B LIC, APPROP. ENDORSED CLASS B LIC              1
# FRAUDULENT POSSESSION OF VEHOWNERSHIP REG. PLATE,CARD                                                        1
# FAIL VEH DRIVER IN ACC.TO RPT.DAMAGE TO NEAREST POLICE                                                       1
# DISPLAYING / PERMITTING TO BE DISPLAYED REG. PLATE ISSUED  TO OTHER PERSON                                   1
# MOTOR VEH. EQUIPPED WITH UNLAWFULLY MODIFIED EXHAUST SYSTEM/ NOISE ABATEMENT DEVICE                          1
# DRIVING WHILE LIC. SUSP. UNDE 16-206A2                                                                       1
# OPER. VEH. NOT APPROP. REG., OWNER NOT IN COMPLIANCE W/INSPECTION, MAINTENANCE, REPAIR REQ.                  1
# SELLING NEW FARM EQUIPMENT W/O SLOW MOVING VEH. EMBLEM                                                       1
# STOPPING, STANDING, ON AUTHORITY HIGHWAY WHEN PROHIBITED                                                     1
# DRIVER ON DUTY, OPERATING  COMMERICAL VEHICLE WHILE POSSESSING  BEER                                         1
# DRIVER OF VEH. DRIVING OVER UNPROTECTED FIRE HOSE LAID O HWY., PRIVATE DRIVEWAY) W/O CONSENT                 1
# FAIL VEH DRIVER IN ACC.TO RPT BODILY INJ COLLISION TO NEAREST POLICE                                         1
# DRIVING WHILE LIC. SUSP. UNDER 16-203, 16-206A2 FAIL TO ATTEND DIP, 17-106, 26-204/206, 27-101               1
# FAIL TO NOTIFY POLICE AFTER CRASH                                                                            1
# WEIGHT VIOLATIONS ON HIGHWAYS AND INTERSTATES EXCEEDING ALLOWABLE WEIGHT OF 8000LBS BY 25355LBS              1
# DRIVING WHILE SUSP. UNDER  26-204                                                                            1
# DISPLAYING  TO BE DISPLAYED REG. PLATE ISSUED FOR OTHER VEHICLE  TO OTHER PERSON                             1
# DRIVING WHILE LIC. SUSP. UNDER1 16-206A2 FAIL TO ATTEND DIP,                                                 1
# DRIVING WHILE LIC. SUSP. UNDER 4223, 4217                                                                    1
# DRIVING VEHW/ TV-TYPE RECEIVING EQUIP, THAT IS ON AND VISIBLE TO THE DRIVER)ON HWY                           1
# FAIL VEH DRIVER IN ACC.TO RPTVEH. DAMAGETO NEAREST POLICE                                                    1
# DRIVING WHILE LIC. SUSP. UNDER 5808, 6222                                                                    1
# DRIVING WHILE SUSP. UNDER 16-203,17-106, 26-204/206, 27-103                                                  1
# EXCEEDING ALLOWABLE AXLE WEIGHT EXCEEDING ALLOWABLE WEIGHT OF 35000LBS BY 5300LBS                            1
# FAILURE OF VEH. DRIVER TO USE CARE TO AVOID COLLISION W/ BIKE,EPAMD,MOTOR SCOOTER OPER. BY PERSON            1
# DISPLAYING PLATES TO OTHER PERSON                                                                            1
# OPERATING A COMMERCIAL MOTOR VEHICLE, CMV, W/O A CDL WHEN REQUIRED                                           1
# OBSTRUCT WITH OPERATION OF TRANSIT VEH., RAILROAD PASSENGER CAR                                              1
# DRIVER FAILURE TO OBEY RR GRADE CROSSING GATE AND BARRIER                                                    1
# DRIVING WHILE LIC. SUSP. UNDER 4217,5720                                                                     1
# FRAUDULENT POSSESSION OF VEH OWNERSHIP REG. PLATE, CARD                                                      1
# DRIVER FAIL TO COMPLY WITH LOCAL LAWS - NO TRUCKS OVER 7000LBS GVW                                           1
# DRIVING VEH. ON HWY. IN VIOLATION OF WEIGHT LAWS EXCEEDING ALLOWABLE WEIGHT OF 11000LBS BY 1100LBS           1
# THROWING ANY REFUSE - CIGARETTE BUTT - ON HWY.                                                               1
# DRIVING VEHW/ VIDEO DISPEQUIP THAT IS ON AND VISIBLE TO THE DRIVER ON HWY                                    1
# DRIVING VEH. WITH PASSENGER OVERLOAD INTERFERING WITH DRIVER CONTROL)                                        1
# PERSON DRIVING MOTOR VEH. ON HWY.ON CANCELLED OUT OF STATE LIC.                                              1
# DRIVING MOTOR VEH. ON HWY, WEARING HEADSET OVER EARS                                                         1
# MATERIALLY ALTERING, VEH. EQUIPMENT AFTER  REPAIR ORDER) CERT. ISSUED.                                       1
# PERSON DRIVING MOTOR VEH. ON HWY., PUBLIC USE PROPERTY) ON REVOKED LIC. AND PRIVILEGE                        1
# FRAUDULENT POSSESSION OF VEH OWNERSHIP REG. PLATE ID PLATES                                                  1
# PROVISIONAL DRIVER UNDER 18 DRIVING M/V W/PASSENGER UNDER 18 -SECONDARY ACTION                               1
# DRIVING VEH WHILE SO FAR IMPAIRED BY  ALCO CANNOT DRIVE SAFELY                                               1
# DRIVER WRITING MSG. WHILE OPER. VEH. IN TRAVEL PORTION OF HWY                                                1
# OPER. M/V OWNED  BY OPERATOR'S EMPLOYER NOT EQUIPPED WITH AN IGNITION INTERLOCK AS REQ.                      1
# KNOWINGLY USING FALSIFIED VEH. DOCUMENT AND REG. PLATE                                                       1
# FAILURE OF VEH. DRIVER TO DISPLAY CURRENT REG. PLATES AND CARRY CURRENT REG. CARD)                           1
# FAILURE TO NOTIFY POLICE DEPT. WITHIN 1 HOUR AFTER TOWING, REMOVING VEH. FROM LOT                            1
# DRIVER STARTING VEH. FROM POSITION WHEN UNSAFE                                                               1
# DRIVING VEH ON HWY. IN VIOLATION OF WEIGHT LAWS EXCEEDING ALLOWABLE WEIGHT OF 13000LBS BY 2900LBS            1
# THROWING  OBJECTS AT VEH. OR ITS OCCUPANTS                                                                   1
# WILLFULLY VIOLATING RULES, REGS. OF INSPECTION PROCEDURES AND INSPECTION REQUIREMENTS                        1
# OPERATING MOTOR VEHICLE WITH FLAT TIRE, AXLE 4 BOTH SIDES                                                    1
# HOLDER OF NON-COMMERCIAL CLASS C DR. LIC. DRIVE TO DR. ON HWY M/V OF THE TYPE AUTH BY LIC                    1
# KNOWINGLY USING FALSIFIED, REG. PLATE                                                                        1
# DISPLAY EXP TAGS                                                                                             1
# OPERATING A COMBINATION OF VEHICLES EXC 55 FEET IN LENGTH ON OTHER THAN DESIGNATED HIGHWAY                   1
# DRIVER FAIL TO COMPLY WITH LOCAL LAWS-NO CMV OVER 4 WHEELS OR 6 TONS W/OUT PERMIT                            1
# FAILURE TO ENSURE THAT SAFETY CHAINS ARE PROPERLY ATTACHED TO TOWED VEH. & FRAME OF TOWING VEH.-NONE         1
# ATT.TO DRIVE VEH. WHILE SO FAR IMPAIRED BY DRUG CANNOT DRIVE SAFELY                                          1
# PERSON DRIVING MOTOR VEH. ON HWY WITH REVOKED OUT OF STATE LIC.                                              1
# DRIVER FAIL TO COMPLY WITH LOCAL LAWS-NO THRU TRUCKS OVER 7000LBS GVWR                                       1
# LEARNER'S                                                                                                    1
# MATERIALLY ALTERING  VEH. EQUIPMENT AFTER  REPAIR ORDER  CERT. ISSUED.                                       1
# DRIVER READING ELECTRNIC MSG. WHILE OPER. VEH. IN TRAVEL PORTION OF HWY                                      1
# DRIVING, ATT.TO DRIVE VEH. WHILE SO FAR IMPAIRED BY DRUGS CANNOT DRIVE SAFELY                                1
# ERSON DRIVING MOTOR VEH. ON HWY ON CANCELLED OUT OF STATE LIC.                                               1
# DEPOSIT  ANY REFUSE ON HWY.                                                                                  1
# PEDESTRIAN FAIL TO OBE                                                                                       1
# PERSON DRIVING, ON HWY.VEH WITH VISIBLE BLUE DEVICE                                                          1
# BRAKE HOSE INADEQUATE AND NOT SECURED AGAINST DAMAGE                                                         1
# FAILURE OF MV OPER. DRIVING ON HWY TO  BE IN POSS.OF EVID. OF REQ'D SECURITY FOR MV                          1
# OPERATING MOTOR VEHICLE WITH MISSING, LOOSE WHEEL FASTENERS- 1 STUD MISSING 1 LOOSE LEFT REAR                1
# DISPLAY  FICTITIOUS LIC.                                                                                     1
# ATTACHING UNAUTHORIZED VEH. REG. PLATE WITH INTENTTO , MISREPRESENT VEH. OWNER ID                            1
# DRIVING M/V W/I 12 HOURS AFTER ARREST FOR VIOL OF TR 21-902.                                                 1
# OUT OF STATE EXPIRED LIC                                                                                     1
# DISPLAYING REG. PLATE ISSUED FOR OTHER VEHICLE .                                                             1
# DISPLAY a REVOKED LIC.                                                                                       1
# MODIFYING  EXHAUST SYSTEM, NOISE ABATEMENT DEVICE ON MOTOR VEH. CAUSING EXCESSIVE NOISE EMISSION             1
# FRAUDULENT POSSESSION OF VEH OWNERSHIP REG. PLATE AND CARD                                                   1
# MATERIALLY ALTERING VEH. EQUIPMENT AFTER REPAIR ORDER CERT. ISUED.                                           1
# DRIVING WHILE LIC. SUSP. UNDER 4217                                                                          1
# MOTOR VEH. EQUIPPED WITH UNLAWFULLY MODIFIED EXHAUST SYSTEM DEVICE)                                          1
# DRIVER BACKING MOTOR VEH. ON OADWAY OF CONTROLLED ACCESS HWY.                                                1
# UNLAWFUL USE OF HISTORIC PASSENGER VEH., TRUCK FOR EMPLOYMENT                                                1
# WILLFULLY DISOBEYING DIRECTION) OF A POLICE OFFICER                                                          1
# DRIVER FAIL TO COMPLY WITH LOCAL LAWS -NO COMM VEH OVER 4 WHEELS OR 6 TONS                                   1
# FAIL VEH DRIVER IN ACC.TO RPT. ATTENDED VEH DAMAGE TO NEAREST POLICE                                         1
# MATERIALLY/ALTERING, VEH. EQUIPMENT AFTER  REPAIR ORDER CERT. ISSUED.                                        1
# DRIVING, VEH WHILE SO FAR IMPAIRED BY DRUGS & ALCOHO) CANNOT DRIVE SAFELY                                    1
# DRIVING WHILE LIC. SUSP. UNDER 5697 CHILD SUPPORT                                                            1
# PEQUIP THAT IS ON AND VISIBLE TO THE DRIVER ON HWY                                                           1
# DRIVING WHILE LIC. SUSP. UNDER 16-203, 17-106, 26-204/206, OR 27-103                                         1
# DRIVING, ATTEMPTING TO DRIVE VEH. WHILE SO FAR IMPAIRED BY DRUGSCANNOT DRIVE SAFELY                          1
# DISPLAYING REG. PLATE ISSUED VEHICLE                                                                         1
# DRIVING VEH. ON HWY. IN VIOLATION OF WEIGHT LAWS EXCEEDING ALLOWABLE WEIGHT OF 13000LBS BY 9400LBS           1
# MATERIALLY ALTERING,VEH. EQUIPMENT AFTER  REPAIR ORDER CERT. ISSUED.                                         1
# DRIVE,ATTEMPT TO DRIVE VEH. WHILE IMPAIRED BY DRUGS WHILE TRANSP. MINOR                                      1
# INSECURE PINTLE HOOK LATCH                                                                                   1
# DRIVING VEH. ON HWY. IN VIOLATION OF WEIGHT LAWS EXCEEDING ALLOWABLE WEIGHT OF 8000LBS BY 3900LBS            1
# DRIVING VEH NOT EQUIPPED WITH AN IGNITION INTERLOCK AS REQUIRED BY PROGRAM                                   1
# CAUSE, PERMIT TO BE DISPLAYED FICTITIOUS LIC.                                                                1
# DRIVING WHILE LIC. SUSP. UNDER 16-204                                                                        1
# DRIVER FAIL TO COMPLY WITH LOCAL LAWS- NO TRUCKS OVER 4 WHEELS OR 12000LBS                                   1
# DRIVER FAIL TO COMPLY WITH LOCAL LAWS- STOP LIGHT                                                            1
# BRAKES ON VEHICLE, COMBINATION OF VEHICLE ARE OUT OF ADJUSTMENT                                              1
# THROWING TRASH ON HIGHWAY                                                                                    1
# DRIVE COMBINATION VEHICLE W/WT RATING OF 28000                                                               1
# DRIVING VEH. ON HWY. IN VIOLATION OF WEIGHT LAWS EXCEEDING ALLOWABLE WEIGHT OF 11000LBS BY 10600LBS          1
# MOTORCYCLE WITH IMPROPER LIGHTING EMITTING A RED, BLUE LIGHT                                                 1
# WILLFULLY DISOBEYING OF A POLICE OFFICER                                                                     1
# DISPLAYING, REG. PLATES ISSUED FOR OTHER VEH                                                                 1
# PERSON DRIVING MOTOR VEH. ON HWY., PUBLIC USE PROPERTY  ON REVOKED LIC. AND PRIVILEGE                        1
# DRIVING VEH W/ TV-TYPE RECEIVING EQUIP, VIDEO EQUIP THAT IS ON AND VISIBLE TO THE DRIVER)ON HWY              1
# DISPLAYING  TO BE DISPLAYED) REG. PLATE ISSUED FOR OTHER VEHICLE                                             1
# DRIVING W/O B LIC                                                                                            1
# THROWING, DUMPING, DISCHARGE ANY REFUSEON HWY                                                                1
# DRIVER FAIL TO COMPLY WITH LOCAL LAWS- NO VEH / NO COMBO VEH OVER 10,000LBS GVWR / GCWR                      1
# DRIVER OPERATE,  COMMERCIAL MV WHEN DRIVER IS DISQUALIFIED                                                   1
# STANDING  VEH. W/I 30 FT OF FLASHING SIGNAL                                                                  1
# DRIVING VEH. ON HWY. IN VIOLATION OF WEIGHT LAWS EXCEEDING ALLOWABLE WEIGHT OF 64000LBS BY 900LBS            1
# NOT EQUIPPED WITH EXHAUST MUFFLER SYSTEM                                                                     1
# DRIVING WHILE LIC. SUSP. UNDER 16-203,17-106, 26-204/206, 27-103)                                            1
# DRIVING WHILE LIC. SUSP. UNDER 16-206 CHILD SUPPORT                                                          1
# PERSON DRIVING ON HWY. VEH.,  WITH VISIBLE  BLUE  DEVICE                                                     1
# UNLAWFUL USE OF HISTORIC PASSENGER VEH.,OR GENERAL DAILY TRANSPORTATION                                      1
# OPERATING MOTOR VEHICLE WITH FLAT TIRE, AXLE 2 RIGHT SIDE OUTER TIRE                                         1
# DRIVING TO DRIVE) VEH. WHILE SO FAR IMPAIRED BY DRUGS CANNOT DRIVE SAFELY                                    1
# FAIL APPLY W/IN 48 HOURS FOR REPLACEMENT OF AFFIX-ED CURRENT REG.PLATE,TABS                                  1
# FAILURE OF MV OPER. DRIVING ON HWY TO  CARRY  EVID. OF REQ'D SECURITY FOR MV                                 1
# Name: Description, dtype: int64

# %%
# Write the processed data to a CSV
processed_file_path = "data\Traffic_Violations_Processed.csv"
big_df_smaller.to_csv(processed_file_path, index=False)
